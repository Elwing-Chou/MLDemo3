# %%
# https://github.com/Elwing-Chou/MLDemo3
import pandas as pd
traindf = pd.read_csv("poem_train.csv", encoding="utf-8")
traindf
# Out:
#        作者                  詩名  \
# 0      李白         菩薩蠻·平林漠漠煙如織
# 1      李白                把酒問月
# 2      李白                  春思
# 3      李白              春夜洛城聞笛
# 4      李白              古風 其十九
# 5      李白                 關山月
# 6      李白      將進酒·君不見黃河之水天上來
# 7      李白             夢遊天姥吟留彆
# 8      李白         菩薩蠻·舉頭忽見衡陽雁
# 9      李白            清平樂·禁庭春晝
# 10     李白            清平樂·禁闈清夜
# 11     李白                 蜀道難
# 12     李白                 送友人
# 13     李白       聞王昌齡左遷龍標，遙有此寄
# 14     李白                 俠客行
# 15     李白              行路難 其二
# 16     李白              行路難 其一
# 17     李白         行路難·有耳莫洗潁川水
# 18     李白         宣州謝朓樓餞彆校書叔雲
# 19     李白             憶秦娥·簫聲咽
# 20     李白                 玉階怨
# 21     李白                古朗月行
# 22     李白                 短歌行
# 23     李白                 從軍行
# 24     李白                  秋思
# 25     李白                  秋思
# 26     李白               峨眉山月歌
# 27     李白                越中覽古
# 28     李白                 從軍行
# 29     李白               獨坐敬亭山
# ...

# %%
testdf = pd.read_csv("poem_test.csv", encoding="utf-8")
testdf
# Out:
#      作者                    詩名  \
# 0    李白                 望廬山瀑布
# 1    李白                 早發白帝城
# 2    李白                   贈汪倫
# 3    李白               送孟浩然之廣陵
# 4    李白                  夜宿山寺
# 5    李白                   靜夜思
# 6    李白                  望天門山
# 7    李白                 獨坐敬亭山
# 8    李白                登金陵鳳凰台
# 9    李白                 渡荊門送彆
# 10   杜甫                  彆讚上人
# 11   杜甫                   龍門鎮
# 12   杜甫                   木皮嶺
# 13   杜甫                    落日
# 14   杜甫          入奏行贈西山檢察使竇侍禦
# 15   杜甫                    麗春
# 16   杜甫               題玄武禪師屋壁
# 17   杜甫                 謁文公上方
# 18   杜甫                    杜鵑
# 19   杜甫                   縛雞行
# 20  白居易                    聽歌
# 21  白居易                  追歡偶作
# 22  白居易             酬夢得貧居詠懷見贈
# 23  白居易              閒坐看書貽諸少年
# 24  白居易  二年三月五日齋畢開素當食偶吟贈妻弘農郡君
# 25  白居易                履道西門二首
# 26  白居易                 昨日複今辰
# 27  白居易                 不與老為期
# 28  白居易                    閒眠
# 29  白居易   和李相公留守題漕上新橋六韻　同用黎字。
#
# ...

# %%
import jieba
def cutpoem(poem):
    return " ".join(jieba.cut(poem)).replace("\r", "").replace("\n", "")
traindf["內容"] = traindf["內容"].apply(cutpoem)
traindf
# Out:
#        作者                  詩名  \
# 0      李白         菩薩蠻·平林漠漠煙如織
# 1      李白                把酒問月
# 2      李白                  春思
# 3      李白              春夜洛城聞笛
# 4      李白              古風 其十九
# 5      李白                 關山月
# 6      李白      將進酒·君不見黃河之水天上來
# 7      李白             夢遊天姥吟留彆
# 8      李白         菩薩蠻·舉頭忽見衡陽雁
# 9      李白            清平樂·禁庭春晝
# 10     李白            清平樂·禁闈清夜
# 11     李白                 蜀道難
# 12     李白                 送友人
# 13     李白       聞王昌齡左遷龍標，遙有此寄
# 14     李白                 俠客行
# 15     李白              行路難 其二
# 16     李白              行路難 其一
# 17     李白         行路難·有耳莫洗潁川水
# 18     李白         宣州謝朓樓餞彆校書叔雲
# 19     李白             憶秦娥·簫聲咽
# 20     李白                 玉階怨
# 21     李白                古朗月行
# 22     李白                 短歌行
# 23     李白                 從軍行
# 24     李白                  秋思
# 25     李白                  秋思
# 26     李白               峨眉山月歌
# 27     李白                越中覽古
# 28     李白                 從軍行
# 29     李白               獨坐敬亭山
# ...

# %%
testdf["內容"] = testdf["內容"].apply(cutpoem)
testdf
# Out:
#      作者                    詩名  \
# 0    李白                 望廬山瀑布
# 1    李白                 早發白帝城
# 2    李白                   贈汪倫
# 3    李白               送孟浩然之廣陵
# 4    李白                  夜宿山寺
# 5    李白                   靜夜思
# 6    李白                  望天門山
# 7    李白                 獨坐敬亭山
# 8    李白                登金陵鳳凰台
# 9    李白                 渡荊門送彆
# 10   杜甫                  彆讚上人
# 11   杜甫                   龍門鎮
# 12   杜甫                   木皮嶺
# 13   杜甫                    落日
# 14   杜甫          入奏行贈西山檢察使竇侍禦
# 15   杜甫                    麗春
# 16   杜甫               題玄武禪師屋壁
# 17   杜甫                 謁文公上方
# 18   杜甫                    杜鵑
# 19   杜甫                   縛雞行
# 20  白居易                    聽歌
# 21  白居易                  追歡偶作
# 22  白居易             酬夢得貧居詠懷見贈
# 23  白居易              閒坐看書貽諸少年
# 24  白居易  二年三月五日齋畢開素當食偶吟贈妻弘農郡君
# 25  白居易                履道西門二首
# 26  白居易                 昨日複今辰
# 27  白居易                 不與老為期
# 28  白居易                    閒眠
# 29  白居易   和李相公留守題漕上新橋六韻　同用黎字。
#
# ...

# %%
transdict = {"李白":0, "杜甫":1, "白居易":2}
ytrain = traindf["作者"].replace(transdict)
ytest = testdf["作者"].replace(transdict)

# %%
from sklearn.feature_extraction.text import CountVectorizer
vec = CountVectorizer()
trainvec = vec.fit_transform(traindf["內容"])
testvec = vec.transform(testdf["內容"])

# %%
len(vec.vocabulary_)
# Out:
# 52294

# %%
print(trainvec)
# Out:
#   (0, 33975)	1
#   (0, 34)	1
#   (0, 44987)	2
#   (0, 26005)	1
#   (0, 3797)	1
#   (0, 50568)	1
#   (0, 13846)	1
#   (0, 3549)	1
#   (0, 31382)	1
#   (0, 25180)	1
#   (0, 23289)	1
#   (0, 51400)	1
#   (0, 39345)	1
#   (0, 4756)	1
#   (0, 139)	1
#   (0, 14002)	1
#   (0, 30177)	1
#   (0, 29006)	1
#   (0, 16053)	1
#   (1, 30274)	1
#   (1, 23255)	1
#   (1, 46243)	1
#   (1, 32285)	1
#   (1, 9506)	1
#   (1, 12473)	1
#   :	:
#   (2729, 39706)	1
#   (2729, 50638)	1
#   (2729, 684)	1
#   (2730, 23226)	1
#   (2730, 8048)	1
#   (2730, 51689)	1
#   (2730, 28423)	1
#   (2730, 38489)	1
#   (2730, 28820)	1
#   (2730, 39190)	1
#   (2730, 1714)	1
#   (2730, 7813)	1
#   (2730, 48596)	1
#   (2730, 6770)	1
#   (2730, 49196)	1
#   (2730, 35446)	1
#   (2730, 40974)	1
#   (2730, 31125)	1
#   (2730, 2175)	1
#   (2730, 29458)	1
#   (2730, 44854)	1
#   (2730, 15905)	1
#   (2730, 36958)	1
#   (2730, 6026)	1
#   (2730, 25782)	1

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
clf.fit(trainvec, ytrain)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
pre = clf.predict(testvec)
from sklearn.metrics import accuracy_score
accuracy_score(pre, ytest)
# Out:
# 0.8

# %%
from sklearn.metrics import confusion_matrix
pd.DataFrame(confusion_matrix(ytest, pre))
# Out:
#    0  1  2
# 0  8  1  1
# 1  1  8  1
# 2  1  1  8

# %%
a = """黃子佼籌備多時的個人專輯預計年底發行，日前突傳因為歌曲版權問題，「妳像風」一曲無法收錄於專輯內，讓他崩潰暴哭數回，內心既沮喪又失落。今天凌晨他透過臉書報告好消息，表示一位天使音樂人只花7個小時便交出作品，「除了感動，還是感動，我該怎麼才能回報呢？」

事發至今邁入第3天，他Po影片解釋整起事件的來龍去脈，也向陳建寧、黃韻玲等傳來私訊的明星好友致謝，更不忘感謝女友孟耿如的相伴，昨天下午3點左右他收到一則願意幫忙的私訊，他說：「有種冥冥中註定的感覺，其中有次開案，我跟這位音樂人邀過歌，不是用WhatsApp、Line、臉書，而是用MSN，他有給我（歌）。」可惜最終專輯沒錄成，這回有望合作，黃子佼說：「我很驚訝也很激動，在後台眼淚掉不停。」

對方花7小時交出作品，他花了2小時填詞，預計今晚進錄音室，得以達成10首歌的圓滿夢想，今有媒體指出對方是五月天阿信，黃子佼稍早也公布了對方身分，「謝謝你五月天團隊，謝謝你，阿信老師。這下一輩子欠著了，我不想一直被逼哭，這兩天哭一年的量，我只想事情順利點。」倒是阿信對消息外流感到訝異，聽聞黃子佼道歉之後，表示沒有關係，「遲早要跟大家（說）的，只是好快阿！」"""
from jieba.analyse import extract_tags
print(extract_tags(a, 5))
# Out:
# ['阿信', '專輯', '預計', '臉書', '音樂人']
