# %%
# http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
import glob
import pandas as pd
traindf = pd.DataFrame(columns=["content", "sentiment"])
for fn in glob.glob("aclImdb/train/neg/*.txt"):
    # f = open(fn, "r", encoding="utf-8")
    with open(fn, "r", encoding="utf-8") as f:
        article = f.read()
    s = pd.Series([article, 0], index=["content", "sentiment"])
    traindf = traindf.append(s, ignore_index=True)
for fn in glob.glob("aclImdb/train/pos/*.txt"):
    # f = open(fn, "r", encoding="utf-8")
    with open(fn, "r", encoding="utf-8") as f:
        article = f.read()
    s = pd.Series([article, 1], index=["content", "sentiment"])
    traindf = traindf.append(s, ignore_index=True)
traindf
# Out:
#                                                  content sentiment
# 0      Story of a man who has unnatural feelings for ...         0
# 1      Airport '77 starts as a brand new luxury 747 p...         0
# 2      This film lacked something I couldn't put my f...         0
# 3      Sorry everyone,,, I know this is supposed to b...         0
# 4      When I was little my parents took me along to ...         0
# 5      "It appears that many critics find the idea of...         0
# 6      The second attempt by a New York intellectual ...         0
# 7      I don't know who to blame, the timid writers o...         0
# 8      This film is mediocre at best. Angie Harmon is...         0
# 9      The film is bad. There is no other way to say ...         0
# 10     This film is one giant pant load. Paul Schrade...         0
# 11     The plot for Descent, if it actually can be ca...         0
# 12     Plot is not worth discussion even if it hints ...         0
# 13     This film is about a male escort getting invol...         0
# 14     This movie must be in line for the most boring...         0
# 15     A worn-out plot of a man who takes the rap for...         0
# 16     I saw this movie at a drive-in in 1959. Until ...         0
# 17     Ghost of Dragstrip Hollow is a typical 1950's ...         0
# 18     "Ghost of Dragstrip Hollow" was one of the man...         0
# 19     "Ghost of Dragstrip Hollow" appears to take pl...         0
# 20     The characters are unlikeable and the script i...         0
# 21     Kareena Kapoor in a bikini hmmmmmmmm.<br /><br...         0
# 22     I rented this on DVD and I kind of feel bad si...         0
# 23     Vijay Krishna Acharya's 'Tashan' is a over-hyp...         0
# 24     The worst movie I have seen since Tera Jadoo C...         0
# 25     Summer season is here when the choices in the ...         0
# 26     Shame on Yash Raj films and Aditya Chopra who ...         0
# 27     First lesson that some film makers (particular...         0
# 28     If this is a 2008 product from one of the bigg...         0
# 29     I had some expectation for the movie, since it...         0
# ...                                                  ...       ...
# 24970  its not as good as the first movie,but its a g...         1
# 24971  Sure, it was cheesy and nonsensical and at tim...         1
# 24972  SPOILERS THROUGH: <br /><br />I really am in t...         1
# 24973  I have to say, I loved Vanishing Point. I've s...         1
# 24974  To start off with, since this movie is a remak...         1
# 24975  I have to agree with most of the other posts. ...         1
# 24976  Any movie that shows federal PIGs (Persons In ...         1
# 24977  In Canadian director Kari Skogland's film adap...         1
# 24978  I saw this movie last night after waiting ages...         1
# 24979  This movie is about basically human relations,...         1
# 24980  I was surprised at just how much I enjoyed thi...         1
# 24981  I saw this film in Winnipeg recently - appropr...         1
# 24982  As perhaps one of the few Canadians who did no...         1
# 24983  I was very moved by the story and because I am...         1
# 24984  What I loved about the on-screen adaptation of...         1
# 24985  I had a chance to see a screening of this movi...         1
# 24986  This is a really interesting movie. It is an a...         1
# 24987  I saw the movie recently and really liked it. ...         1
# 24988  I thought this movie was hysterical. I have wa...         1
# 24989  ...this is a classic with so many great dialog...         1
# 24990  The most hillarious and funny Brooks movie I e...         1
# 24991  "Life stinks" is a parody of life and death, h...         1
# 24992  This is the kind of film you want to see with ...         1
# 24993  I have not read the other comments on the film...         1
# 24994  Life Stinks (1991) was a step below Mel Brooks...         1
# 24995  Seeing as the vote average was pretty low, and...         1
# 24996  The plot had some wretched, unbelievable twist...         1
# 24997  I am amazed at how this movie(and most others ...         1
# 24998  A Christmas Together actually came before my t...         1
# 24999  Working-class romantic drama from director Mar...         1
#
# [25000 rows x 2 columns]

# %%
testdf = pd.DataFrame(columns=["content", "sentiment"])
for fn in glob.glob("aclImdb/test/neg/*.txt"):
    # f = open(fn, "r", encoding="utf-8")
    with open(fn, "r", encoding="utf-8") as f:
        article = f.read()
    s = pd.Series([article, 0], index=["content", "sentiment"])
    testdf = testdf.append(s, ignore_index=True)
for fn in glob.glob("aclImdb/test/pos/*.txt"):
    # f = open(fn, "r", encoding="utf-8")
    with open(fn, "r", encoding="utf-8") as f:
        article = f.read()
    s = pd.Series([article, 1], index=["content", "sentiment"])
    testdf = testdf.append(s, ignore_index=True)
testdf
# Out:
#                                                  content sentiment
# 0      Once again Mr. Costner has dragged out a movie...         0
# 1      This is an example of why the majority of acti...         0
# 2      First of all I hate those moronic rappers, who...         0
# 3      Not even the Beatles could write songs everyon...         0
# 4      Brass pictures (movies is not a fitting word f...         0
# 5      A funny thing happened to me while watching "M...         0
# 6      This German horror film has to be one of the w...         0
# 7      Being a long-time fan of Japanese film, I expe...         0
# 8      "Tokyo Eyes" tells of a 17 year old Japanese g...         0
# 9      Wealthy horse ranchers in Buenos Aires have a ...         0
# 10     Cage plays a drunk and gets high critically pr...         0
# 11     First of all, I would like to say that I am a ...         0
# 12     So tell me - what serious boozer drinks Budwei...         0
# 13     A big disappointment for what was touted as an...         0
# 14     This film is absolutely appalling and awful. I...         0
# 15     Here's a decidedly average Italian post apocal...         0
# 16     At the bottom end of the apocalypse movie scal...         0
# 17     Earth has been destroyed in a nuclear holocaus...         0
# 18     Many people are standing in front of the house...         0
# 19     New York family is the last in their neighborh...         0
# 20     The best thing about "The Prey" is the tag lin...         0
# 21     This is truly, without exaggerating, one of th...         0
# 22     I'm a huge fan of both Emily Watson (Breaking ...         0
# 23     Sure, most of the slasher films of the 1980's ...         0
# 24     I think that would have been a more appropriat...         0
# 25     1980 was certainly a year for bad backwoods sl...         0
# 26     Everything everyone has said already pretty mu...         0
# 27     Uhhh ... so, did they even have writers for th...         0
# 28     Oh yeah, this one is definitely a strong conte...         0
# 29     Supercraptastic slasher fare, which feels over...         0
# ...                                                  ...       ...
# 24970  this movie has a decent story in my opinion,ve...         1
# 24971  When you think of golf movies, you think of Ca...         1
# 24972  When i first saw the movie being advertised i ...         1
# 24973  If you like your sports movies to be about dig...         1
# 24974  Rainy day with not much to do. We were surfing...         1
# 24975  Where would Hollywood have been without Fredri...         1
# 24976  Shia LaBeouf has impressed me before with his ...         1
# 24977  This is not a movie that I would typically wat...         1
# 24978  Both Disney and Bill Paxton did a fine job in ...         1
# 24979  Disney's Buena Vista Pictures presents a wonde...         1
# 24980  I was blown away by this film. I'm one of thos...         1
# 24981  This is first of all a good, exciting story, w...         1
# 24982  I am not a golf fan by any means. On May 26 ab...         1
# 24983  THE GREATEST GAME EVER PLAYED (TGGEP, 2005) is...         1
# 24984  The focus of the key relationship in a young m...         1
# 24985  I thought that this movie was incredible. I ab...         1
# 24986  With its ww2 timing, falling in and out of lov...         1
# 24987  Oh my god what a story! This movie is very goo...         1
# 24988  At 20 years old, Francis Ouimet (Shia Lebouf) ...         1
# 24989  I will divide my review into following 5 categ...         1
# 24990  if you watch this at home on DVD or Bluray! be...         1
# 24991  I'm not a sports fan - but I love sports flics...         1
# 24992  As you know "The Greatest Game Ever Played" is...         1
# 24993  This movie gives golf a high mark, it was well...         1
# 24994  Wow, here is another great golf movie. That's ...         1
# 24995  I was extraordinarily impressed by this film. ...         1
# 24996  Although I'm not a golf fan, I attended a snea...         1
# 24997  From the start of "The Edge Of Love", the view...         1
# 24998  This movie, with all its complexity and subtle...         1
# 24999  I've seen this story before but my kids haven'...         1
#
# [25000 rows x 2 columns]
